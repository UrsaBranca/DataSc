# %% [markdown]
# # How to complete this assignment
# First, download [this Kaggle dataset](https://www.kaggle.com/hugomathien/soccer) and extract *sqlite* database. You may need to register at https://www.kaggle.com/ beforehand. Then complete 15 graded tasks below, the score is given in brackets. Finally submit the resulting `.ipynb` file to rs-app Auto-test.
#
# - Do not delete or rename the variables given before the inscription `#your code here`, they are needed for the correct verification.
# - Do not change the code in the last Notebook cell, it is required for the server check.
# - Your Notebook must run completely without errors to be graded! Please check everything before submission by going *Cell -> Run All*

# %% [markdown]
# ## Some important notes
# - If you need to **calculate the number of "something"** that means we expect you to assign an Integer to the given variable
# - If you need to **make a list of "something"** we expect you to assign a Python list with appropriate values to the given variable
# - If you need to find a **specifiс player, day of the week, team, etc.** we expect you to assign a String with the full name of the entity to the given variable (`player_name`, day of week full name, `team_name`, etc.)

# %%
import sqlite3
import pandas as pd
import os

pd.set_option('display.max_column', None)

# %%
# Leave that code unchanged, it is required for the server check!
db = sqlite3.connect(os.environ.get("DB_PATH") or 'database.sqlite')

# %%
# You may load the data from SQL table directly to the Pandas dataframe as
player_data = pd.read_sql("SELECT * FROM Player;", db)

# %%
player_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11060 entries, 0 to 11059
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  11060 non-null  int64
#  1   player_api_id       11060 non-null  int64
#  2   player_name         11060 non-null  object
#  3   player_fifa_api_id  11060 non-null  int64
#  4   birthday            11060 non-null  object
#  5   height              11060 non-null  float64
#  6   weight              11060 non-null  int64
#  7   year                11060 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 691.4+ KB

# %%
player_data.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %% [markdown]
# **Task 1 (0.25 point).** Calculate the number of players with a height between 180 and 190 inclusive

# %%
player_data[(player_data.height >= 180) & (player_data.height <= 190)]
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# 5          6          27316           Aaron Hunt              158138
# 10        11          23889        Aaron Mokoena               47189
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 3      1982-05-08 00:00:00  182.88     198
# ...

# %%
players_180_190 = len(player_data[(player_data.height >= 180) & (player_data.height <= 190)])
players_180_190

# or
# player_data.loc[((player_data.height >= 180) & (player_data.height <= 190)), 'height'].count() # or ...'id/weight/etc.'].count()
# Out:
# 5925

# %%
assert(isinstance(players_180_190, int))

# %% [markdown]
# **Task 2 (0.25 point).** Calculate the number of players born in 1980. <br>
# **Hint:** you may want to cast your 'birthday' column to DateTime type by [pandas.to_datetime](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html)

# %%
player_data.loc[player_data['birthday'].str.startswith('1980')]
# Out:
#           id  player_api_id            player_name  player_fifa_api_id  \
# 10        11          23889          Aaron Mokoena               47189
# 46        47          37280        Abdoulaye Meite               41745
# 134      135          26136        Adama Coulibaly                5440
# 193      194          41109                Adriano              152769
# 262      263          30248             Alan Smith               13739
# ...      ...            ...                    ...                 ...
# 10966  10982          38215  Youssef Wasef Mohamad              164042
# 10967  10983          25538         Youssouf Hadji              116368
# 11010  11026          30861         Zdenek Grygera               40988
# 11011  11027          36547           Zdenek Kroca              185004
# 11031  11047          19696              Zhi Zheng              158293
#
#                   birthday  height  weight
# 10     1980-11-25 00:00:00  182.88     181
# ...

# %%
# players_1980 = player_data.birthday.apply(lambda date: date[:4] == '1980').sum() 
# - с sum() не проходит assert, хотя рез в инте и все норм
# решение: добавить в конце послу sum() .item()
players_1980 = player_data.birthday.apply(lambda date: date[:4] == '1980').sum().item()

# этот вариант работает и без добавления .item() 
# players_1980 = len(player_data.loc[player_data['birthday'].str.startswith('1980')])
players_1980

# or
# player_data.loc[:, 'birthday'].apply(lambda date: date[:4] == '1980').value_counts()[1]
# or
# player_data['birthday'].str.startswith('1980').sum()
# Out:
# 434

# %%
assert(isinstance(players_1980, int))

# %% [markdown]
# **Task 3 (0.25 point).** Make a list of the top 10 players with the highest weight sorted in descending order. If there are several players with the same weight put them in the lexicographic order by name.

# %%
player_data.sort_values(by = ['weight', 'player_name'], ascending = [False, True]).iloc[:10]['player_name'].to_list()
# Out:
# ['Kristof van Hout',
#  'Tim Wiese',
#  'Jeroen Verhoeven',
#  'Ishmael Miller',
#  'Cassio',
#  'Christopher Samba',
#  'Lars Unnerstall',
#  'Marcus Hahnemann',
#  'Abdoulaye Faye',
#  'Enoch Showunmi']

# %%
highest_players = player_data.sort_values(by = ['weight', 'player_name'], ascending = [False, True]).iloc[:10]['player_name'].to_list()

# %%
assert(len(highest_players) == 10)
assert(isinstance(highest_players, list))
for i in range(10):
    assert(isinstance(highest_players[i], str))

# %% [markdown]
# **Task 4 (0.5 point).** Make a list of tuples containing years along with the number of players born in that year from 1980 up to 1990. <br>
# **Structure example**: [(1980, 123), (1981, 140) ..., (1990, 83)] -> There were born 123 players in 1980, there were born 140 players in 1981 and etc.

# %%
#player_data[(player_data.height >= 180) & (player_data.height <= 190)]
#player_data['birthday'].str.slice(start=0, stop=4) == 1980

# player_data['pd_80_90'] = player_data.birthday.apply(lambda date: date[:4] if (date[:4] >= '1980') & (date[:4] <= '1990') else 0)
# player_data

player_data['year'] = player_data.birthday.apply(lambda date: date[:4]).astype(int)
player_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight  year
# 0      1992-02-29 00:00:00  182.88     187  1992
# ...

# %%
# var 2 - with DateTime

import datetime

def what_year(row):
    dt = datetime.datetime.strptime(row.birthday, '%Y-%m-%d %H:%M:%S').date()
    return dt.year

player_data['year'] = player_data.apply(what_year, axis = 'columns')
player_data
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight  year
# 0      1992-02-29 00:00:00  182.88     187  1992
# ...

# %%
list(
    player_data[(player_data.year >= 1980) & (player_data.year <= 1990)]
      ['year']
      .value_counts()
      .sort_index(ascending = True)
      .items()
)
# Out:
# [(1980, 434),
#  (1981, 475),
#  (1982, 487),
#  (1983, 541),
#  (1984, 607),
#  (1985, 593),
#  (1986, 710),
#  (1987, 722),
#  (1988, 802),
#  (1989, 723),
#  (1990, 696)]

# %%
# def tpl(row):
#     data = (row.birthday[:4], row.height)
#     return data
    
# pd_80_90.apply(tpl, axis = 'columns')
# Out:
# 1        (1989, 170.18)
# 3        (1982, 182.88)
# 5        (1986, 182.88)
# 7         (1987, 165.1)
# 9        (1987, 175.26)
#               ...
# 11053    (1988, 180.34)
# 11054     (1989, 190.5)
# 11056    (1986, 182.88)
# 11058    (1981, 185.42)
# 11059    (1982, 180.34)
# Length: 6790, dtype: object

# %%
years_born_players = list(
    player_data[(player_data.year >= 1980) & (player_data.year <= 1990)]
      ['year']
      .value_counts()
      .sort_index(ascending = True)
      .items()
)

# %%
assert(len(years_born_players) == 11)
assert(isinstance(years_born_players, list))
for i in range(10):
    assert(isinstance(years_born_players[i], tuple))
    assert(isinstance(years_born_players[i][0], int))
    assert(isinstance(years_born_players[i][1], int))

# %% [markdown]
# **Task 5 (0.5 point).** Calculate the mean and the standard deviation of the players' **height** with the name **Adriano**. <br>
# **Note:** Name is represented by the first part of `player_name`.

# %%
# players_Adriano = player_data.player_name.apply(lambda name:name.split(' ')[0] == 'Adriano')
# player_data[players_Adriano]['height'].mean(), player_data[players_Adriano]['height'].std()
# Out:
# (182.118, 5.361479480723788)

# %%
players_Adriano = (
    player_data
      .player_name
      .apply(lambda name: name.split(' ')[0] == 'Adriano')
)

adriano_mean, adriano_std = (
    player_data[players_Adriano]['height']
      .describe()[['mean','std']]
)

adriano_mean, adriano_std
# Out:
# (182.118, 5.361479480723788)

# %%
assert(isinstance(adriano_mean, float))
assert(isinstance(adriano_std, float))

# %% [markdown]
# **Task 6 (0.75 point).** How many players were born on each day of the week? Find the day of the week with the minimum number of players born.

# %%
def what_dow(row):
    dt = datetime.datetime.strptime(row.birthday, '%Y-%m-%d %H:%M:%S').date()
    return dt.isoweekday()

#dow_names = {1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'}

import calendar
dow_names = list(calendar.day_name)

# %%
dow_with_min_players_born = (
    player_data
      .apply(what_dow, axis = 'columns')
      .value_counts()
      .rename(lambda i: dow_names[i - 1])
      .idxmin()
)

dow_with_min_players_born
# Out:
# 'Sunday'

# %%
assert(isinstance(dow_with_min_players_born, str))

# %% [markdown]
# **Task 7 (0.75 point).** Find a league with the most matches in total. If there are several leagues with the same amount of matches, take the first in the lexical order.

# %%
# You may load the data from SQL table directly to the Pandas dataframe as
match_data = pd.read_sql("SELECT * FROM Match;", db)
league_data = pd.read_sql("SELECT * FROM League;", db)
match_data.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        492473              9987              9993               1
# 1        492474             10000              9994               0
# 2        492475              9984              8635               0
# 3        492476              9991              9998               5
# 4        492477              7947              9985               1
#
#    away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0               1             NaN             NaN             NaN
# ...

# %%
b = match_data.league_id.value_counts().max()
b
# Out:
# 3040

# %%
leagues_count = (
    match_data
      .groupby(['country_id'])
      .agg({'league_id': 'count'})
      .sort_values(by='league_id', ascending=False)
)

leagues_count
# Out:
#             league_id
# country_id
# 1729             3040
# 4769             3040
# 21518            3040
# 10257            3017
# 7809             2448
# 13274            2448
# 17642            2052
# 15722            1920
# 19694            1824
# 1                1728
# 24558            1422

# %%
max_data = leagues_count.loc[leagues_count['league_id'] == b].reset_index()
max_data
# Out:
#    country_id  league_id
# 0        1729       3040
# 1        4769       3040
# 2       21518       3040

# %%
league_most_matches = pd.merge(
    max_data, 
    league_data, 
    how='inner', 
    on='country_id'
).name[0]

league_most_matches
# Out:
# 'England Premier League'

# %%
assert(isinstance(league_most_matches, str))

# %% [markdown]
# **Task 8 (1.25 point).** Find a player who participated in the largest number of matches during the whole match history. Assign a `player_name` to the given variable

# %%
#def player(column):

col_names = ['home_player_1', 'away_player_11']
index_no = [
    match_data
      .columns
      .get_loc(col_name) for col_name in col_names
]
index_no   

players_data = (
    match_data
      .iloc[
          :, 
          index_no[0]:index_no[1] + 1
      ]
)

#players_data.set_index(match_data.id).dropna(how = 'all')
players_data = players_data.set_index(match_data.match_api_id)

# %%
players_data = players_data.reset_index()
players_data
# Out:
#        match_api_id  home_player_1  home_player_2  home_player_3  \
# 0            492473            NaN            NaN            NaN
# 1            492474            NaN            NaN            NaN
# 2            492475            NaN            NaN            NaN
# 3            492476            NaN            NaN            NaN
# 4            492477            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 25974       1992091        42231.0       678384.0        95220.0
# 25975       1992092        33272.0        41621.0        25813.0
# 25976       1992093       157856.0       274779.0       177689.0
# 25977       1992094            NaN         8881.0       173534.0
# 25978       1992095       274787.0       492132.0       108451.0
#
#        home_player_4  home_player_5  home_player_6  home_player_7  \
# 0                NaN            NaN            NaN            NaN
# ...

# %%
#g = players_data.groupby('home_player_1').agg({'match_api_id': 'count'})

g = pd.concat(
    [g, players_data
          .groupby('home_player_2')
          .agg({'match_api_id': 'count'})]
)

# %%
max_matches_df = (
    players_data
      .groupby('home_player_1')
      .agg({'match_api_id': 'count'})
)

col_names = (
    players_data
      .drop(['match_api_id', 'home_player_1'], axis=1)
      .columns
)

for col_name in col_names:
    max_matches_df = pd.concat(
        [max_matches_df, 
         players_data.groupby(col_name)
           .agg({'match_api_id': 'count'})]
    )

max_matches_df = (
    max_matches_df
      .rename_axis('player_api_id', axis='rows')
      .rename(columns = {'match_api_id':'max_matches'})
      .reset_index()
      .groupby('player_api_id')
      .agg({'max_matches': 'sum'})
)

max_matches_df.reset_index(inplace=True)

# %%
max_matches_players = (
    pd.merge(
      max_matches_df, 
      player_data, 
      how='inner', 
      on='player_api_id'
    )                        
    .sort_values(by='max_matches', ascending=False)
)

max_matches_players
# Out:
#        player_api_id  max_matches     id           player_name  \
# 2089         31293.0          300  10009        Steve Mandanda
# 4029         41097.0          294   9970      Stephane Ruffier
# 2482         33764.0          286   3952  Gorka Iraizoz Moreno
# 4334         42422.0          286   9427      Samir Handanovic
# 1236         26295.0          282   4272           Hugo Lloris
# ...              ...          ...    ...                   ...
# 2371         33118.0            1  10202     Thierry Gathuessi
# 9383        304857.0            1   7579          Milos Bakrac
# 9394        306068.0            1   7820       Nedim Sacirovic
# 2343         33021.0            1    612         Ander Murillo
# 11059       750584.0            1    473     Alexandre Azevedo
#
#        player_fifa_api_id             birthday  height  weight  year
# 2089               163705  1985-03-28 00:00:00  185.42     181  1985
# 4029               167628  1986-09-27 00:00:00  187.96     198  1986
# ...

# %%
max_matches_players.head(30)
# Out:
#       player_api_id  max_matches     id           player_name  \
# 2089        31293.0          300  10009        Steve Mandanda
# 4029        41097.0          294   9970      Stephane Ruffier
# 2482        33764.0          286   3952  Gorka Iraizoz Moreno
# 4334        42422.0          286   9427      Samir Handanovic
# 1236        26295.0          282   4272           Hugo Lloris
# 2117        31465.0          282  10301            Tim Howard
# 2110        31432.0          275   5035              Joe Hart
# 1177        26168.0          268   1613       Cedric Carrasso
# 1289        26399.0          262   2115         Daniel Congre
# 5449        94550.0          260   7731        Moussa Sissoko
# 1979        30893.0          259   1995     Cristiano Ronaldo
# 649         23782.0          258   3661          Gareth Barry
# 3363        38433.0          257   1327          Borja Valero
# 4189        41658.0          257   6779          Marek Hamsik
# ...

# %%
# max_matches_players.iloc[0].player_name
# or - длинно, но как альтернативный вариант, без сортировки
# max_matches_players.iloc[max_matches_players.max_matches.idxmax()].player_name
# Out:
# 'Steve Mandanda'

# %%
max_matches_player = max_matches_players.iloc[0].player_name

# %%
assert(isinstance(max_matches_player, str))

# %% [markdown]
# **Task 9 (1.5 point).** List top-5 tuples of most correlated **player's characteristics** in the descending order of the absolute [Pearson's coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient) value.
#
# **Note 1:** Players characteristics are all the columns in `Player_Attributes` table except `[id, player_fifa_api_id, player_api_id, date, preferred_foot, attacking_work_rate, defensive_work_rate]`). <br>
# **Note 2:** Exclude duplicated pairs from the list. E.g. ('gk_handling', 'gk_reflexes') and ('gk_reflexes', 'gk_handling') are duplicates, leave just one of them in the resulting list.
#
# **Hint:** You may use [dataframe.corr()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) for calculating pairwise Pearson correlation.

# %%
player_attrs = pd.read_sql("SELECT * FROM Player_Attributes;", db)
player_attrs.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
player_attrs_work = (
    player_attrs
      .drop(
        ['id', 'player_fifa_api_id', 'player_api_id', 'date', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate'], 
        axis=1
      )
)

player_attrs_work.head()
# Out:
#    overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0            67.0       71.0      49.0       44.0              71.0
# 1            67.0       71.0      49.0       44.0              71.0
# 2            62.0       66.0      49.0       44.0              71.0
# 3            61.0       65.0      48.0       43.0              70.0
# 4            61.0       65.0      48.0       43.0              70.0
#
#    short_passing  volleys  dribbling  curve  free_kick_accuracy  long_passing  \
# 0           61.0     44.0       51.0   45.0                39.0          64.0
# 1           61.0     44.0       51.0   45.0                39.0          64.0
# 2           61.0     44.0       51.0   45.0                39.0          64.0
# 3           60.0     43.0       50.0   44.0                38.0          63.0
# 4           60.0     43.0       50.0   44.0                38.0          63.0
#
#    ball_control  acceleration  sprint_speed  agility  reactions  balance  \
# ...

# %%
# Create correlation matrix
corr_mat = player_attrs_work.corr(method = 'pearson')

# ---- commented bc with this method there are duplicates ----
# # Convert correlation matrix to 1-D Series and sort
# sorted_mat = corr_mat.unstack().sort_values()
# sorted_mat

# ---- Sort correlation matrix without duplicates ----

# Retain upper triangular values of correlation matrix and
# make Lower triangular values Null
upper_corr_mat = (
    corr_mat
      .where(
        np.triu(np.ones(corr_mat.shape), k=1)
        .astype(bool)
        )
)

# Convert to 1-D series and drop Null values
unique_corr_pairs = upper_corr_mat.unstack().dropna()

# Sort correlation pairs
sorted_mat = unique_corr_pairs.sort_values(ascending = False)
sorted_mat
# Out:
# gk_reflexes      gk_positioning     0.966711
#                  gk_handling        0.966326
# gk_positioning   gk_handling        0.966301
# sliding_tackle   standing_tackle    0.953104
# standing_tackle  marking            0.950134
#                                       ...
# gk_diving        short_passing     -0.693313
# gk_handling      ball_control      -0.732483
# gk_positioning   ball_control      -0.734933
# gk_reflexes      ball_control      -0.737894
# gk_diving        ball_control      -0.740928
# Length: 595, dtype: float64

# %%
top_correlated_features = list(sorted_mat[:5].keys())
top_correlated_features
# Out:
# [('gk_reflexes', 'gk_positioning'),
#  ('gk_reflexes', 'gk_handling'),
#  ('gk_positioning', 'gk_handling'),
#  ('sliding_tackle', 'standing_tackle'),
#  ('standing_tackle', 'marking')]

# %%
assert(len(top_correlated_features) == 5)
assert(isinstance(top_correlated_features, list))
for i in range(5):
    assert(isinstance(top_correlated_features[i], tuple))
    assert(isinstance(top_correlated_features[i][0], str))
    assert(isinstance(top_correlated_features[i][1], str))

# %% [markdown]
# **Task 10 (2 points).** Find top-5 most similar players to **Neymar** whose names are given. The similarity is measured as [Euclidean distance](https://en.wikipedia.org/wiki/Euclidean_distance) between vectors of players' characteristics (described in the task above). Put their names in a vector in ascending order by Euclidean distance and sorted by `player_name` if the distance is the same<br>
# **Note 1:** There are many records for some players in the `Player_Attributes` table. You need to take the freshest data (characteristics with the most recent `date`). <br>
# **Note 2:** Use pure values of the characteristics even if you are aware of such preprocessing technics as normalization. <br>
# **Note 3:** Please avoid using any built-in methods for calculating the Euclidean distance between vectors, think about implementing your own.

# %%
player_attrs.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
player_attrs['new_date_format'] = pd.to_datetime(player_attrs['date'])

# %%
g = player_attrs.groupby(['player_api_id']).agg({'new_date_format': 'max'})
g.reset_index()
# Out:
#        player_api_id new_date_format
# 0               2625      2015-01-16
# 1               2752      2015-10-16
# 2               2768      2016-03-17
# 3               2770      2013-07-05
# 4               2790      2010-08-30
# ...              ...             ...
# 11055         744907      2016-06-09
# 11056         746419      2016-05-12
# 11057         748432      2016-05-12
# 11058         750435      2016-04-14
# 11059         750584      2016-05-19
#
# [11060 rows x 2 columns]

# %%
m = pd.merge(
        g, 
        player_attrs.drop('new_date_format', axis=1), 
        how='inner', 
        on='player_api_id'
)

m = m.drop_duplicates(subset=['player_api_id', 'new_date_format'])


player_attrs_work = m.drop(
    ['id', 'player_fifa_api_id', 'date', 'preferred_foot', 
    'attacking_work_rate', 'defensive_work_rate', 'new_date_format'], 
    axis=1
)

player_attrs_work
# Out:
#         player_api_id  overall_rating  potential  crossing  finishing  \
# 0                2625            61.0       61.0      50.0       47.0
# 14               2752            72.0       72.0      39.0       40.0
# 35               2768            74.0       74.0      44.0       45.0
# 56               2770            69.0       69.0      58.0       66.0
# 71               2790            67.0       77.0      72.0       37.0
# ...               ...             ...        ...       ...        ...
# 183952         744907            53.0       67.0      43.0       45.0
# 183963         746419            59.0       66.0      55.0       28.0
# 183965         748432            58.0       68.0      48.0       26.0
# 183967         750435            60.0       74.0      35.0       57.0
# 183976         750584            58.0       66.0      47.0       39.0
#
#         heading_accuracy  short_passing  volleys  dribbling  curve  \
# ...

# %%
# var 2 - простой способ:
# его особенность (позитивная?), что сохраняются индексы из оригинального дф player_attrs

player_attrs_work = (
    player_attrs
      .sort_values(by = ['player_api_id', 'date'], ascending = [True, False])
      .drop_duplicates('player_api_id')
      .drop(['id', 'player_fifa_api_id', 'date', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate'], axis=1)
)

player_attrs_work.sort_values('player_api_id')
# Out:
#         player_api_id  overall_rating  potential  crossing  finishing  \
# 139843           2625            61.0       61.0      50.0       47.0
# 44144            2752            72.0       72.0      39.0       40.0
# 88284            2768            74.0       74.0      44.0       45.0
# 72141            2770            69.0       69.0      58.0       66.0
# 5121             2790            67.0       77.0      72.0       37.0
# ...               ...             ...        ...       ...        ...
# 66601          744907            53.0       67.0      43.0       45.0
# 58304          746419            59.0       66.0      55.0       28.0
# 60179          748432            58.0       68.0      48.0       26.0
# 147408         750435            60.0       74.0      35.0       57.0
# 8085           750584            58.0       66.0      47.0       39.0
#
#         heading_accuracy  short_passing  volleys  dribbling  curve  \
# ...

# %%
player_attrs_work = (
    pd.merge(
      player_attrs_work, 
      player_data[['player_api_id', 'player_name']], 
      how='left', 
      on='player_api_id'
    )
    .set_index('player_api_id')
)

player_attrs_work
# Out:
#                overall_rating  potential  crossing  finishing  \
# player_api_id
# 2625                     61.0       61.0      50.0       47.0
# 2752                     72.0       72.0      39.0       40.0
# 2768                     74.0       74.0      44.0       45.0
# 2770                     69.0       69.0      58.0       66.0
# 2790                     67.0       77.0      72.0       37.0
# ...                       ...        ...       ...        ...
# 744907                   53.0       67.0      43.0       45.0
# 746419                   59.0       66.0      55.0       28.0
# 748432                   58.0       68.0      48.0       26.0
# 750435                   60.0       74.0      35.0       57.0
# 750584                   58.0       66.0      47.0       39.0
#
#                heading_accuracy  short_passing  volleys  dribbling  curve  \
# player_api_id
# 2625                       46.0           52.0     39.0       50.0   51.0
# ...

# %%
player_data[player_data.player_name == 'Neymar']
# Out:
#         id  player_api_id player_name  player_fifa_api_id  \
# 7855  7867          19533      Neymar              190871
#
#                  birthday  height  weight  year
# 7855  1992-02-05 00:00:00  175.26     150  1992

# %%
player_attrs_work.loc[19533]['player_name']
# Out:
# 'Neymar'

# %%
type(player_attrs_work.loc[19533].drop('player_name'))
# Out:
# pandas.core.series.Series

# %%
id_Neymar = player_data[player_data.player_name == 'Neymar']['player_api_id'].item()
x_serie = player_attrs_work.loc[id_Neymar].drop('player_name')

def eu_dist(y_serie):
    #print(x_serie)
    dist = np.sqrt(np.sum([(x_n - y_n)*(x_n - y_n) for x_n, y_n in zip(x_serie, y_serie)])) 
    return dist

dist_serie = player_attrs_work.apply(eu_dist, axis = 'columns')

# %%
dist_serie_5 = dist_serie.sort_values().iloc[1:6]     # the 1st is Neymar himself
dist_serie_5
# Out:
# player_api_id
# 325916    33.837849
# 107417    34.957117
# 41157     38.314488
# 30834     40.024992
# 30981     43.543082
# dtype: float64

# %%
dist_serie_5 = dist_serie_5.sort_index().sort_values()   # чтобы при равных dist была сортировка по имени
dist_serie_5
# Out:
# player_api_id
# 325916    33.837849
# 107417    34.957117
# 41157     38.314488
# 30834     40.024992
# 30981     43.543082
# dtype: float64

# %%
def sims():
    neymar_similarities_list = []

    for i in dist_serie_5.keys():
        #print(i, end = ': ')
        name = player_data[player_data.player_api_id == i]['player_name'].item()
        #print(name)
        neymar_similarities_list.append(name)
    return neymar_similarities_list
        
print(sims())
# Out:
# ['Paulo Dybala', 'Eden Hazard', 'Giovani dos Santos', 'Arjen Robben', 'Lionel Messi']

# %%
# # через преобразование к df и join, а не через цикл по серии

# dist_data_5 = dist_serie_5.to_frame()
# dist_data_5.rename(columns = {0:'dist'})

# df_join = dist_data_5.join(player_data.set_index('player_api_id')\
#                                        ['player_name'].sort_values(), how='left') 
# df_join

# %%
neymar_similarities = sims()

# %%
assert(len(neymar_similarities) == 5)
assert(isinstance(neymar_similarities, list))
for i in range(5):
    assert(isinstance(neymar_similarities[i], str))

# %% [markdown]
# **Task 11 (1 point).** Calculate the number of home matches played by the **Borussia Dortmund** team in **Germany 1. Bundesliga** in season **2008/2009**

# %%
team_data = pd.read_sql("SELECT * FROM Team;", db)

# %%
home_matches = (
    match_data[match_data['season'] == '2008/2009']
    .loc[:, ('country_id', 'home_team_api_id', 'match_api_id')]
)

home_matches
# Out:
#        country_id  home_team_api_id  match_api_id
# 0               1              9987        492473
# 1               1             10000        492474
# 2               1              9984        492475
# 3               1              9991        492476
# 4               1              7947        492477
# ...           ...               ...           ...
# 24732       24558              9931        486305
# 24733       24558              9956        486306
# 24734       24558              7955        486307
# 24735       24558              6493        486308
# 24736       24558              9824        486309
#
# [3326 rows x 3 columns]

# %%
team_data.head()
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
league_data.head()
# Out:
#       id  country_id                    name
# 0      1           1  Belgium Jupiler League
# 1   1729        1729  England Premier League
# 2   4769        4769          France Ligue 1
# 3   7809        7809   Germany 1. Bundesliga
# 4  10257       10257           Italy Serie A

# %%
home_matches_gr = (
    home_matches
      .groupby(['home_team_api_id', 'country_id'])
      .agg({'match_api_id': 'count'})
      .reset_index()
      .rename(columns = {'home_team_api_id':'team_api_id'})
)

home_matches_gr
# Out:
#      team_api_id  country_id  match_api_id
# 0           1601       15722            15
# 1           1957       15722            15
# 2           2182       15722            15
# 3           2183       15722            15
# 4           2186       15722            15
# ..           ...         ...           ...
# 183        10264       17642            15
# 184        10265       15722            15
# 185        10267       21518            19
# 186        10269        7809            17
# 187        10281       21518            19
#
# [188 rows x 3 columns]

# %%
b = pd.merge(home_matches_gr, team_data, how='inner', on='team_api_id')     
b
# Out:
#      team_api_id  country_id  match_api_id     id  team_fifa_api_id  \
# 0           1601       15722            15  31446             874.0
# 1           1957       15722            15  31456          110745.0
# 2           2182       15722            15  31453             873.0
# 3           2183       15722            15  31448            1570.0
# 4           2186       15722            15  31458          110747.0
# ..           ...         ...           ...    ...               ...
# 183        10264       17642            15  35290            1896.0
# 184        10265       15722            15  31443            1873.0
# 185        10267       21518            19  43035             461.0
# 186        10269        7809            17  15632              36.0
# 187        10281       21518            19  43050             462.0
#
#             team_long_name team_short_name
# 0             Ruch Chorzów             CHO
# 1    Jagiellonia Białystok             BIA
# ...

# %%
d = pd.merge(b, league_data, how='inner', on='country_id')  
d
# Out:
# C:\Users\Olga Pavlova\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#      team_api_id  country_id  match_api_id   id_x  team_fifa_api_id  \
# 0           1601       15722            15  31446             874.0
# 1           1957       15722            15  31456          110745.0
# 2           2182       15722            15  31453             873.0
# 3           2183       15722            15  31448            1570.0
# 4           2186       15722            15  31458          110747.0
# ..           ...         ...           ...    ...               ...
# 183         9875       10257            19  20526              48.0
# 184         9882       10257            19  20527            1837.0
# 185         9885       10257            19  20522              45.0
# ...

# %%
borussia_bundesliga_2008_2009_matches = (
    d[
      d['team_long_name'] == 'Borussia Dortmund'
    ]
      .loc[:, ('name', 'match_api_id')]
      .iloc[0, d.columns.get_loc('match_api_id')-1]
      .item()
)

borussia_bundesliga_2008_2009_matches
# Out:
# 17

# %%
assert(isinstance(borussia_bundesliga_2008_2009_matches, int))

# %% [markdown]
# **Task 12 (1 point).** Find a team having the most matches (both home and away!) in the **Germany 1. Bundesliga** in **2008/2009** season. Return number of matches.

# %%
germany_id = league_data[league_data['name'] == 'Germany 1. Bundesliga']['country_id'].item()
germany_id
# Out:
# 7809

# %%
total_matches = (
    match_data[
      (match_data['season'] == '2008/2009') & (match_data['country_id'] == germany_id)
    ]
      .loc[:, ('country_id', 'home_team_api_id', 'away_team_api_id', 'match_api_id')]
)
                        
total_matches
# Out:
#       country_id  home_team_api_id  away_team_api_id  match_api_id
# 7808        7809              9823              9790        499317
# 7809        7809              8178              9789        499318
# 7810        7809             10189              9904        499319
# 7811        7809              8721              8722        499320
# 7812        7809              9810              8177        499321
# ...          ...               ...               ...           ...
# 8109        7809             10189              9912        499393
# 8110        7809              8398              9810        499394
# 8111        7809              9904              8697        499395
# 8112        7809              9788              8295        499396
# 8113        7809              8226              9790        499397
#
# [306 rows x 4 columns]

# %%
# total_matches.groupby(['home_team_api_id']).agg({'match_api_id': 'count'}).idxmax().item(),\
# total_matches.groupby(['away_team_api_id']).agg({'match_api_id': 'count'}).idxmax().item()
# Out:
# (8177, 8177)

# %%
total_matches.groupby(['home_team_api_id']).agg({'match_api_id': 'count'}).max().item(),\
total_matches.groupby(['away_team_api_id']).agg({'match_api_id': 'count'}).max().item()
# Out:
# (17, 17)

# %%
team_most_matches_bundesliga_2008_2009 = (
    total_matches
      .groupby(['home_team_api_id'])
      .agg({'match_api_id': 'count'})
      .max().item() 
    +  
    total_matches
      .groupby(['away_team_api_id'])
      .agg({'match_api_id': 'count'})
      .max().item()
)

team_most_matches_bundesliga_2008_2009
# Out:
# 34

# %%
assert(isinstance(team_most_matches_bundesliga_2008_2009, int))

# %% [markdown]
# **Task 13 (1 point).** Count total number of **Arsenal** matches (both home and away!) in the **2015/2016** season which they have won. <br><br>
# **Note:** Winning a game means scoring **more** goals than an opponent.

# %%
arsenal_id = team_data[team_data['team_long_name'] == 'Arsenal']['team_api_id'].item()
arsenal_id
# Out:
# 9825

# %%
arsenal_matches = (
    match_data[(match_data['season'] == '2015/2016') & \
               ((match_data['home_team_api_id'] == arsenal_id) | (match_data['away_team_api_id'] == arsenal_id))]
      .loc[:, ('match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal')]
)

arsenal_matches.head()
# Out:
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 4388       1987032              9825              8654               0
# 4398       1988800              9825              8668               2
# 4414       1988816             10003              9825               0
# 4418       1988820              9825              8586               1
# 4437       1988839              8659              9825               2
#
#       away_team_goal
# 4388               2
# 4398               1
# 4414               3
# 4418               1
# 4437               1

# %%
def if_won(row):
    if row['home_team_api_id'] == arsenal_id:
        if row.home_team_goal > row.away_team_goal:
            return True
        else:
            return False
        
    elif row['away_team_api_id'] == arsenal_id:
        if row.away_team_goal > row.home_team_goal:
            return True
        else:
            return False

arsenal_matches['won'] = arsenal_matches.apply(if_won, axis = 'columns')
arsenal_matches.head()
# Out:
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 4388       1987032              9825              8654               0
# 4398       1988800              9825              8668               2
# 4414       1988816             10003              9825               0
# 4418       1988820              9825              8586               1
# 4437       1988839              8659              9825               2
#
#       away_team_goal    won
# 4388               2  False
# 4398               1   True
# 4414               3   True
# 4418               1  False
# 4437               1  False

# %%
arsenal_won_matches_2015_2016 = arsenal_matches['won'].sum().item()
arsenal_won_matches_2015_2016
# Out:
# 20

# %%
assert(isinstance(arsenal_won_matches_2015_2016, int))

# %% [markdown]
# **Task 14 (2 points).** Find a team with the highest win rate in the **2015/2016** season. Win rate means won matches / all matches. If there are several teams with the highest win rate return the first by name in lexical order

# %%
len(all_teams_matches.match_api_id.unique())
# Out:
# 3326

# %%
all_teams_matches = (
    match_data[
      (match_data['season'] == '2015/2016')
    ]
      .loc[:, ('match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal')]
)

all_teams_matches.head()
# Out:
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 1488       1979832              9997              8342               2
# 1489       1979833              8571              9985               2
# 1490       1979834              9987              1773               3
# 1491       1979835              8573              8203               3
# 1492       1979836             10000              9994               3
#
#       away_team_goal
# 1488               1
# 1489               1
# 1490               1
# 1491               1
# 1492               1

# %%
all_teams_matches['home_win'] = all_teams_matches.home_team_goal > all_teams_matches.away_team_goal
all_teams_matches['away_win'] = all_teams_matches.away_team_goal > all_teams_matches.home_team_goal
all_teams_matches
# Out:
#        match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 1488        1979832              9997              8342               2
# 1489        1979833              8571              9985               2
# 1490        1979834              9987              1773               3
# 1491        1979835              8573              8203               3
# 1492        1979836             10000              9994               3
# ...             ...               ...               ...             ...
# 25974       1992091             10190             10191               1
# 25975       1992092              9824             10199               1
# 25976       1992093              9956             10179               2
# 25977       1992094              7896             10243               0
# 25978       1992095             10192              9931               4
#
#        away_team_goal  home_win  away_win
# 1488                1      True     False
# ...

# %%
home_wins = (
    all_teams_matches
      .groupby('home_team_api_id')
      .agg({'match_api_id': 'count', 'home_win' : 'sum'})
      .rename(columns = {'home_win':'wins', 'match_api_id': 'matches'})
)

home_wins
# Out:
#                   matches  wins
# home_team_api_id
# 1601                   15     6
# 1773                   15     6
# 1957                   15     6
# 2182                   15     6
# 2186                   15     7
# ...                   ...   ...
# 158085                 17     8
# 177361                 15     5
# 188163                 17     3
# 208931                 19     6
# 274581                 15     3
#
# [188 rows x 2 columns]

# %%
away_wins = (
    all_teams_matches
      .groupby('away_team_api_id')
      .agg({'match_api_id': 'count', 'away_win' : 'sum'})
      .rename(columns = {'away_win':'wins', 'match_api_id': 'matches'})
)

away_wins
# Out:
#                   matches  wins
# away_team_api_id
# 1601                   15     5
# 1773                   15     1
# 1957                   15     4
# 2182                   15     7
# 2186                   15     5
# ...                   ...   ...
# 158085                 17     5
# 177361                 15     3
# 188163                 17     5
# 208931                 19     3
# 274581                 15     4
#
# [188 rows x 2 columns]

# %%
df = (
    home_wins
      .add(away_wins, fill_value=0)
      .rename_axis('team_api_id', axis='rows')
)

df['win_rate'] = df.wins / df.matches
df
# Out:
#              matches  wins  win_rate
# team_api_id
# 1601              30    11  0.366667
# 1773              30     7  0.233333
# 1957              30    10  0.333333
# 2182              30    13  0.433333
# 2186              30    12  0.400000
# ...              ...   ...       ...
# 158085            34    13  0.382353
# 177361            30     8  0.266667
# 188163            34     8  0.235294
# 208931            38     9  0.236842
# 274581            30     7  0.233333
#
# [188 rows x 3 columns]

# %%
df = (
    df
      .drop(['matches', 'wins'], axis=1)
      .join(
        team_data.set_index('team_api_id')
        ['team_long_name'], 
        how='left'
      )
      .sort_values(by = ['win_rate', 'team_long_name'], ascending=[False, True])
)

df
# Out:
#              win_rate       team_long_name
# team_api_id
# 9772         0.852941           SL Benfica
# 9823         0.823529     FC Bayern Munich
# 9768         0.794118          Sporting CP
# 9847         0.789474  Paris Saint-Germain
# 8640         0.764706                  PSV
# ...               ...                  ...
# 8020         0.133333        Polonia Bytom
# 9876         0.131579        Hellas Verona
# 7788         0.088235           SC Cambuur
# 10252        0.078947          Aston Villa
# 10242        0.078947         ES Troyes AC
#
# [188 rows x 2 columns]

# %%
team_highest_winrate_2015_2016 = df.team_long_name.iloc[0]
team_highest_winrate_2015_2016
# Out:
# 'SL Benfica'

# %%
assert(isinstance(team_highest_winrate_2015_2016, str))

# %% [markdown]
# **Task 15 (2 points).** Determine the team with the maximum days' gap between matches in **England Premier League 2010/2011 season**. Return number of days in that gap. <br>
# **Note**: a *gap* means the number of days between two consecutive matches of the same team.

# %%
epl_id = league_data[league_data['name'] == 'England Premier League']['country_id'].item()
epl_id
# Out:
# 1729

# %%
epl_matches = (
    match_data[
      (match_data['season'] == '2010/2011') & (match_data['country_id'] == epl_id)
    ]
      .loc[:, ('match_api_id', 'date', 'home_team_api_id', 'away_team_api_id')]
)
                    
epl_matches['date'] = pd.to_datetime(epl_matches['date'])
epl_matches
# Out:
#       match_api_id       date  home_team_api_id  away_team_api_id
# 2488        839796 2010-08-14             10252              8654
# 2489        839797 2010-08-14              8655              8668
# 2490        839799 2010-08-14              8559              9879
# 2491        839800 2010-08-14              8455              8659
# 2492        839801 2010-08-15              8650              9825
# ...            ...        ...               ...               ...
# 2863        839899 2010-10-23              8658              8483
# 2864        839900 2010-10-23              8659              9879
# 2865        839901 2010-10-24             10194             10260
# 2866        839902 2010-10-23              8528              8559
# 2867        839903 2010-10-23              8455              8602
#
# [380 rows x 4 columns]

# %%
melt_epl_matches = pd.melt(
    epl_matches, 
    id_vars=['match_api_id', 'date'], 
    value_vars=('home_team_api_id','away_team_api_id'), 
    var_name='type_of_play', 
    value_name='team_api_id', 
    col_level=None
)

melt_epl_matches
# Out:
#      match_api_id       date      type_of_play  team_api_id
# 0          839796 2010-08-14  home_team_api_id        10252
# 1          839797 2010-08-14  home_team_api_id         8655
# 2          839799 2010-08-14  home_team_api_id         8559
# 3          839800 2010-08-14  home_team_api_id         8455
# 4          839801 2010-08-15  home_team_api_id         8650
# ..            ...        ...               ...          ...
# 755        839899 2010-10-23  away_team_api_id         8483
# 756        839900 2010-10-23  away_team_api_id         9879
# 757        839901 2010-10-24  away_team_api_id        10260
# 758        839902 2010-10-23  away_team_api_id         8559
# 759        839903 2010-10-23  away_team_api_id         8602
#
# [760 rows x 4 columns]

# %%
# var 1: криво и печально - через двойную сортировку + допстолбцы:

# melt_epl_matches = melt_epl_matches.sort_values(by=['team_api_id', 'date'])
# melt_epl_matches['diff'] = pd.to_datetime(melt_epl_matches['date']).diff().dt.days

# melt_epl_matches.sort_values(by=['team_api_id', 'date']).head(40)

# %%
# var 2: повеселее, через группировку

players_ids = np.sort(melt_epl_matches['team_api_id'].unique())
players_ids
# Out:
# array([ 8455,  8456,  8472,  8483,  8528,  8559,  8586,  8602,  8650,
#         8654,  8655,  8658,  8659,  8668,  9825,  9879, 10194, 10252,
#        10260, 10261], dtype=int64)

# %%
g = (
    melt_epl_matches
      .sort_values(by=['date'])
      .groupby('team_api_id')
      .apply(lambda x: x['date'].diff().dt.days)
)

max_gap = [0, 0]
for id in players_ids:
    if g[id].max() > max_gap[1]:
        max_gap[1] = g[id].max()
        max_gap[0] = id
print(max_gap)

# группировка со сложными вычислениями по колонкам
# df_price = df.groupby(by=['price_levels'],as_index=False)[['CRIM','LSTAT']].apply(lambda v: v.max()-v.min())
# df_price
# Out:
# [8650, 18.0]

# %%
team_data[team_data['team_api_id'] == max_gap[0]]['team_long_name'].item()
# Out:
# 'Liverpool'

# %%
highest_gap_england_2010_2011 = int(max_gap[1])
highest_gap_england_2010_2011
# Out:
# 18

# %%
assert(isinstance(highest_gap_england_2010_2011, int))

# %% [markdown]
# ### Warning! Do not change anything in the area below

# %%
with open('student_answers.txt', 'w') as file:
    file.write(f"{players_180_190}\n")
    file.write(f"{players_1980}\n")
    file.write(f"{highest_players}\n")
    file.write(f"{years_born_players}\n")
    file.write(f"{round(adriano_mean, 3)} {round(adriano_std, 3)}\n")
    file.write(f"{dow_with_min_players_born}\n")
    file.write(f"{league_most_matches}\n")
    file.write(f"{max_matches_player}\n")
    file.write(f"{';'.join(['%s,%s' % tup for tup in top_correlated_features])};\n")
    file.write(f"{neymar_similarities}\n")
    file.write(f"{borussia_bundesliga_2008_2009_matches}\n")
    file.write(f"{team_most_matches_bundesliga_2008_2009}\n")
    file.write(f"{arsenal_won_matches_2015_2016}\n")
    file.write(f"{team_highest_winrate_2015_2016}\n")
    file.write(f"{highest_gap_england_2010_2011}\n")
